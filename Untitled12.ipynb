# %%
# !pip list
# Out:
# /bin/bash: /home/hamza/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Package                       Version
# ----------------------------- ---------------
# absl-py                       1.4.0
# aiohttp                       3.8.1
# aiosignal                     1.3.1
# alabaster                     0.7.12
# alembic                       1.11.2
# anaconda-client               1.11.2
# anaconda-navigator            2.4.0
# anaconda-project              0.11.1
# anyio                         3.5.0
# appdirs                       1.4.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asgiref                       3.7.2
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %% [markdown]
# We need to install Python, NumPy, Pandas, Matplotlib and Seaborn.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### ANSWER 01 :

# %%
pd.__version__
# Out:
# '2.1.0'

# %% [markdown]
# the version of Pandas that i installed is 2.1.0

# %% [markdown]
# we'll use the California Housing Prices dataset.

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Out:
# /bin/bash: /home/hamza/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2023-09-15 04:39:21--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/plain]
# Saving to: ‘housing.csv.3’
#
# housing.csv.3       100%[===================>]   1.36M   877KB/s    in 1.6s
#
# 2023-09-15 04:39:23 (877 KB/s) - ‘housing.csv.3’ saved [1423529/1423529]

# %%
data=pd.read_csv('housing.csv')
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# ##############################################

# %% [markdown]
# ### ANSWER 02 :

# %%
data.shape
# Out:
# (20640, 10)

# %%
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# there are 10 columns in this data

# %% [markdown]
# #################################################

# %% [markdown]
# ### ANSWER 03 :

# %%
data.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# total_bedrooms is the column that have missing values

# %%
NEW_data=data.total_bedrooms.fillna(data.total_bedrooms.mean(),inplace=True)

# %% [markdown]
# ######################################################

# %% [markdown]
# ### ANSWER 04 :

# %%
data.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# the ocean_proximity column have 5 unique values

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# #################################################

# %% [markdown]
# ### ANSWER 05 :

# %%
NEAR_BAYdata=data[data['ocean_proximity']=='NEAR BAY']

# %%
NEAR_BAYdata
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 19067    -122.45     38.28                20.0       3306.0           503.0
# 19068    -122.47     38.29                14.0       3732.0           846.0
# 19069    -122.45     38.27                25.0       5024.0           881.0
# 19077    -122.49     38.27                 8.0       5092.0           988.0
# 19104    -122.51     38.17                 8.0       5875.0          1115.0
#
# ...

# %%
NEAR_BAYdata.median_house_value.mean()
# Out:
# 259212.31179039303

# %% [markdown]
# the average value of the median_house_value for the houses located near the bay is 259212

# %% [markdown]
# ##########################################################

# %% [markdown]
# ### ANSWER 06 :

# %%
mean_bedrooms=data.total_bedrooms.mean()
mean_bedrooms
# Out:
# 537.8705525375617

# %%
data.total_bedrooms.fillna(mean_bedrooms,inplace=True)

# %%
data.total_bedrooms.mean()
# Out:
# 537.8705525375617

# %%
data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %% [markdown]
# So its the same , it hasn't changed

# %% [markdown]
# #################################################

# %% [markdown]
# ### ANSWER 07 :

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
new_data=data[data['ocean_proximity']=='ISLAND']
new_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8314    -118.32     33.35                27.0       1675.0           521.0
# 8315    -118.33     33.34                52.0       2359.0           591.0
# 8316    -118.32     33.33                52.0       2127.0           512.0
# 8317    -118.32     33.34                52.0        996.0           264.0
# 8318    -118.48     33.43                29.0        716.0           214.0
#
#       population  households  median_income  median_house_value  \
# 8314       744.0       331.0         2.1579            450000.0
# 8315      1100.0       431.0         2.8333            414700.0
# 8316       733.0       288.0         3.3906            300000.0
# 8317       341.0       160.0         2.7361            450000.0
# 8318       422.0       173.0         2.6042            287500.0
#
#      ocean_proximity
# 8314          ISLAND
# 8315          ISLAND
# 8316          ISLAND
# 8317          ISLAND
# ...

# %%
final_data=new_data[['housing_median_age', 'total_rooms', 'total_bedrooms']]
final_data
# Out:
#       housing_median_age  total_rooms  total_bedrooms
# 8314                27.0       1675.0           521.0
# 8315                52.0       2359.0           591.0
# 8316                52.0       2127.0           512.0
# 8317                52.0        996.0           264.0
# 8318                29.0        716.0           214.0

# %%
x = final_data.values
x
# Out:
# array([[  27., 1675.,  521.],
#        [  52., 2359.,  591.],
#        [  52., 2127.,  512.],
#        [  52.,  996.,  264.],
#        [  29.,  716.,  214.]])

# %%
x.T
# Out:
# array([[  27.,   52.,   52.,   52.,   29.],
#        [1675., 2359., 2127.,  996.,  716.],
#        [ 521.,  591.,  512.,  264.,  214.]])

# %%
XTX = np.dot(x.T,x)
XTX
# Out:
# array([[9.6820000e+03, 3.5105300e+05, 9.1357000e+04],
#        [3.5105300e+05, 1.4399307e+07, 3.7720360e+06],
#        [9.1357000e+04, 3.7720360e+06, 9.9835800e+05]])

# %%
INV=np.linalg.inv(XTX)
INV
# Out:
# array([[ 9.19403586e-04, -3.66412216e-05,  5.43072261e-05],
#        [-3.66412216e-05,  8.23303633e-06, -2.77534485e-05],
#        [ 5.43072261e-05, -2.77534485e-05,  1.00891325e-04]])

# %%
y = np.array([950, 1300, 800, 1000, 1300])

# %%
res=np.dot(INV,x.T)
res
# Out:
# array([[-0.00825608, -0.00653208, -0.00232159,  0.02565144,  0.01204934],
#        [-0.00165852,  0.0011141 ,  0.00139656, -0.00103215, -0.00110698],
#        [ 0.00754365, -0.00301964, -0.00455125,  0.00181685,  0.00329418]])

# %%
w=np.dot(res,y)
w
# Out:
# array([23.12330961, -1.48124183,  5.69922946])
